# %%
import matplotlib.pyplot as plt

def waterfall_chart(categories, values):
    plt.figure(figsize=(10, 6))
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars
    for category, value in zip(categories, values):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        cumsum += value
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['Start', 'Category 1', 'Category 2', 'Category 3', 'End']
values = [0, 20, -15, 10, -5]

# Create a waterfall chart
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def waterfall_chart(categories, values):
    plt.figure(figsize=(10, 6))
    
    # Convert values to millions
    values_in_millions = np.array(values) / 1000000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars
    for category, value in zip(categories, values_in_millions):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        cumsum += value
    
    # Setting y-axis ticks in millions
    plt.yticks(np.arange(0, cumsum + 1, 1), ['{}M'.format(int(i)) for i in np.arange(0, cumsum + 1, 1)])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Millions)')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['Start', '584k', '215k', '195k', '104k', '50k', '35k', '5k', '-24k']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def waterfall_chart(categories, values):
    plt.figure(figsize=(10, 6))
    
    # Convert values to millions
    values_in_millions = np.array(values) / 1000000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars
    for category, value in zip(categories, values_in_millions):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        cumsum += value
    
    # Adding the last cumulative bar
    plt.bar(categories[-1], cumsum, color=(0.2, 0.4, 0.6, 0.6))
    
    # Setting y-axis ticks in millions
    plt.yticks(np.arange(0, cumsum + 1, 1), ['{}M'.format(int(i)) for i in np.arange(0, cumsum + 1, 1)])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Millions)')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['Start', '584k', '215k', '195k', '104k', '50k', '35k', '5k', '-24k']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def waterfall_chart(categories, values):
    plt.figure(figsize=(10, 6))
    
    # Convert values to millions
    values_in_millions = np.array(values) / 1000000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars
    for category, value in zip(categories, values_in_millions):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        cumsum += value
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color=(0.2, 0.4, 0.6, 0.6))
    
    # Setting y-axis ticks in millions
    plt.yticks(np.arange(0, cumsum + 1, 1), ['{}M'.format(int(i)) for i in np.arange(0, cumsum + 1, 1)])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Millions)')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['Start', '584k', '215k', '195k', '104k', '50k', '35k', '5k', '-24k']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def waterfall_chart(categories, values):
    plt.figure(figsize=(12, 6))
    
    # Convert values to millions
    values_in_millions = np.array(values) / 1000000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with value labels
    for category, value in zip(categories, values_in_millions):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        # plt.text(category, cumsum + value + 0.1, f'{int(value)}K', ha='center')
        plt.text(category, cumsum + value + 0.1, format_number(value), ha='center')
        cumsum += value
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color=(0.2, 0.4, 0.6, 0.6))
    plt.text('udd', cumsum + 0.1, format_number(cumsum), ha='center')
    # plt.text('udd', cumsum + 0.1, f'{int(cumsum)}k', ha='center')
    
    # Setting y-axis ticks in millions
    plt.yticks(np.arange(0, cumsum + 1, 1), ['{}K'.format(int(i)) for i in np.arange(0, cumsum + 1, 1)])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Millions)')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def waterfall_chart(categories, values):
    plt.figure(figsize=(12, 6))
    
    # Convert values to millions
    values_in_millions = np.array(values) / 1000000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with value labels
    for category, value in zip(categories, values_in_millions):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        plt.text(category, cumsum + value + 0.1, f'{int(value)}M', ha='center')
        cumsum += value
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color=(0.2, 0.4, 0.6, 0.6))
    plt.text('udd', cumsum + 0.1, f'{int(cumsum)}M', ha='center')
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Millions)')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    # if abs(value) >= 1e3:
    #     return '{:.0f}k'.format(value)
    # else:
    return '{:.0f}k'.format(value)

def waterfall_chart(categories, values):
    plt.figure(figsize=(12, 6))
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for category, value in zip(categories, values_in_thousands):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        plt.text(category, cumsum + value + 0.1, format_number(value), ha='center')
        cumsum += value
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color=(0.2, 0.4, 0.6, 0.6))
    plt.text('udd', cumsum + 0.1, format_number(cumsum), ha='center')
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Thousands)')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def waterfall_chart(categories, values):
    plt.figure(figsize=(12, 6))
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for category, value in zip(categories, values_in_thousands):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        plt.text(category, cumsum + value + 0.1, format_number(value), ha='center')
        cumsum += value
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color=(0.2, 0.4, 0.6, 0.6))
    plt.text('udd', cumsum + 0.1, format_number(cumsum), ha='center')
    
    # Setting y-axis ticks in millions
    # y_ticks_in_millions = np.arange(0, cumsum + 1, 1) * 1000
    # plt.yticks(y_ticks_in_millions, ['{}M'.format(int(i / 1000)) for i in np.arange(0, cumsum + 1, 1)])

    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Millions)')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def waterfall_chart(categories, values):
    plt.figure(figsize=(12, 6))
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for i, (category, value) in enumerate(zip(categories, values_in_thousands)):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        plt.text(category, cumsum + value + 0.1, format_number(value), ha='center')
        cumsum += value
        
        # Draw lines between bars (except for the last bar)
        if i < len(categories) - 1:
            plt.plot([category, categories[i + 1]], [cumsum, cumsum], color='black', linestyle='dashed')
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color=(0.2, 0.4, 0.6, 0.6))
    plt.text('udd', cumsum + 0.1, format_number(cumsum), ha='center')
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Thousands)')
    plt.title('Waterfall Chart Example')
    
    # Show the plot
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart with lines between bars
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def waterfall_chart(categories, values):
    plt.figure(figsize=(14, 6))  # Adjusted the size of the graph
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for i, (category, value) in enumerate(zip(categories, values_in_thousands)):
        plt.bar(category, value, bottom=cumsum, color=(0.2, 0.4, 0.6, 0.6))
        plt.text(category, cumsum + value + 0.3, format_number(value), ha='center')  # Adjusted the vertical position
        cumsum += value
        
        # Draw lines between bars (except for the last bar)
        if i < len(categories) - 1:
            plt.plot([category, categories[i + 1]], [cumsum, cumsum], color='gray', linestyle='dashed', linewidth=0.8)
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color=(0.2, 0.4, 0.6, 0.6))
    plt.text('udd', cumsum + 0.3, format_number(cumsum), ha='center')  # Adjusted the vertical position
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Thousands)')
    plt.title('Waterfall Chart Example')
    
    # Adjust y-axis limits to add space above the graph
    plt.ylim(top=cumsum + 5)  # You can adjust the value as needed
    
    # Show the plot
    plt.tight_layout(rect=[0, 0.03, 1, 0.97])  # Adjusted layout with more space at the top
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart with more space above the graph
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def get_bar_color(category, value, next_value):
    if category == 'MTM' or next_value is None:
        return 'mediumslateblue'  # First and last bars are blue
    elif value < next_value:
        return 'lightcoral'  # Increasing bar
    elif value > next_value:
        return 'indianred'  # Decreasing bar
    elif category == 'Other':
        return 'lightyellow'  # 'Other' bar is light yellow
    else:
        return 'gray'  # Unchanged bar

def waterfall_chart(categories, values):
    plt.figure(figsize=(14, 6))  # Adjusted the size of the graph
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for i, (category, value) in enumerate(zip(categories, values_in_thousands)):
        bar_color = get_bar_color(category, value, values_in_thousands[i + 1] if i < len(categories) - 1 else None)
        plt.bar(category, value, bottom=cumsum, color=bar_color)
        plt.text(category, cumsum + value + 0.3, format_number(value), ha='center', color='black')  # Adjusted the vertical position and text color
        cumsum += value
        
        # Draw lines between bars (except for the last bar)
        if i < len(categories) - 1:
            plt.plot([category, categories[i + 1]], [cumsum, cumsum], color='gray', linestyle='dashed', linewidth=0.8)
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color='mediumslateblue')  # Blue color for the last bar
    plt.text('udd', cumsum + 0.3, format_number(cumsum), ha='center', color='black')  # Adjusted the vertical position and text color
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('BOMBOQ type')
    plt.ylabel('Cost')
    plt.title('Waterfall Chart Example')
    
    # Adjust y-axis limits to add space above the graph
    plt.ylim(top=cumsum + 5)  # You can adjust the value as needed
    
    # Show the plot
    plt.tight_layout(rect=[0, 0.03, 1, 0.97])  # Adjusted layout with more space at the top
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart with updated colors
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def get_bar_color(category, value, next_value):
    if category == 'MTM' or next_value is None:
        return 'blue'  # First and last bars are blue
    elif value < next_value:
        return 'lightcoral'  # Increasing bar
    elif value > next_value:
        return 'lightgreen'  # Decreasing bar
    elif category == 'Other':
        return 'lightyellow'  # 'Other' bar is light yellow
    else:
        return 'gray'  # Unchanged bar

def waterfall_chart(categories, values):
    plt.figure(figsize=(14, 5))  # Adjusted the size of the graph
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for i, (category, value) in enumerate(zip(categories, values_in_thousands)):
        bar_color = get_bar_color(category, value, values_in_thousands[i + 1] if i < len(categories) - 1 else None)
        plt.bar(category, value, bottom=cumsum, color=bar_color, edgecolor='none')  # Removed edgecolor to remove the border
        plt.text(category, cumsum + value + 0.3, format_number(value), ha='center', color='black')  # Adjusted the vertical position and text color
        cumsum += value
        
        # Draw lines between bars (except for the last bar)
        if i < len(categories) - 1:
            plt.plot([category, categories[i + 1]], [cumsum, cumsum], color='gray', linestyle='dotted', linewidth=0.8)
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color='blue', edgecolor='none')  # Blue color for the last bar, removed edgecolor
    plt.text('udd', cumsum + 0.3, format_number(cumsum), ha='center', color='black')  # Adjusted the vertical position and text color
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Thousands)')
    plt.title('Waterfall Chart Example')
    
    # Adjust y-axis limits to add space above the graph
    plt.ylim(top=cumsum + 5)  # You can adjust the value as needed
    
    # Remove the top and right spines
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    
    # Show the plot
    plt.tight_layout(rect=[0, 0.03, 1, 0.97])  # Adjusted layout with more space at the top
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart with updated colors and removed border
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def get_bar_color(category, value, next_value):
    if category == 'MTM' or next_value is None:
        return 'blue', 'Total'  # First and last bars are blue
    elif value < next_value:
        return 'lightcoral', 'Increase'  # Increasing bar
    elif value > next_value:
        return 'lightgreen', 'Decrease'  # Decreasing bar
    elif category == 'Other':
        return 'lightyellow', 'Other'  # 'Other' bar is light yellow
    else:
        return 'gray', 'Unchanged'  # Unchanged bar

def waterfall_chart(categories, values):
    plt.figure(figsize=(14, 5))  # Adjusted the size of the graph
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for i, (category, value) in enumerate(zip(categories, values_in_thousands)):
        bar_color, legend_label = get_bar_color(category, value, values_in_thousands[i + 1] if i < len(categories) - 1 else None)
        plt.bar(category, value, bottom=cumsum, color=bar_color, edgecolor='none', label=legend_label)  # Added label for legend
        plt.text(category, cumsum + value + 0.3, format_number(value), ha='center', color='black')  # Adjusted the vertical position and text color
        cumsum += value
        
        # Draw lines between bars (except for the last bar)
        if i < len(categories) - 1:
            plt.plot([category, categories[i + 1]], [cumsum, cumsum], color='gray', linestyle='dotted', linewidth=0.8)
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color='blue', edgecolor='none', label='Total')  # Added label for legend
    plt.text('udd', cumsum + 0.3, format_number(cumsum), ha='center', color='black')  # Adjusted the vertical position and text color
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Thousands)')
    plt.title('Waterfall Chart Example', loc='left')  # Moved title to the left
    
    # Adding legend
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    # Custom legends
    custom_legends = [
        plt.Line2D([0], [0], color='lightcoral', lw=10),
        plt.Line2D([0], [0], color='lightgreen', lw=10),
        plt.Line2D([0], [0], color='lightyellow', lw=10),
        plt.Line2D([0], [0], color='blue', lw=10),
    ]
    custom_legend_labels = ['Increase', 'Decrease', 'Other', 'Total']
    plt.legend(custom_legends, custom_legend_labels, loc='lower left')
    
    # Adjust y-axis limits to add space above the graph
    plt.ylim(top=cumsum + 5)  # You can adjust the value as needed
    
    # Remove the top and right spines
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    
    # Show the plot
    plt.tight_layout(rect=[0, 0.03, 1, 0.97])  # Adjusted layout with more space at the top
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart with updated colors, removed border, added legend, and custom legends
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def get_bar_color(category, value, next_value):
    if category == 'MTM' or next_value is None:
        return 'blue', 'Total'  # First and last bars are blue
    elif value < next_value:
        return 'lightcoral', 'Increase'  # Increasing bar
    elif value > next_value:
        return 'lightgreen', 'Decrease'  # Decreasing bar
    elif category == 'Other':
        return 'lightyellow', 'Other'  # 'Other' bar is light yellow
    else:
        return 'gray', 'Unchanged'  # Unchanged bar

def waterfall_chart(categories, values):
    plt.figure(figsize=(14, 5))  # Adjusted the size of the graph
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for i, (category, value) in enumerate(zip(categories, values_in_thousands)):
        bar_color, legend_label = get_bar_color(category, value, values_in_thousands[i + 1] if i < len(categories) - 1 else None)
        plt.bar(category, value, bottom=cumsum, color=bar_color, edgecolor='none', label=legend_label)  # Added label for legend
        plt.text(category, cumsum + value + 0.3, format_number(value), ha='center', color='black')  # Adjusted the vertical position and text color
        cumsum += value
        
        # Draw lines between bars (except for the last bar)
        if i < len(categories) - 1:
            plt.plot([category, categories[i + 1]], [cumsum, cumsum], color='gray', linestyle='dotted', linewidth=0.8)
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color='blue', edgecolor='none', label='Total')  # Added label for legend
    plt.text('udd', cumsum + 0.3, format_number(cumsum), ha='center', color='black')  # Adjusted the vertical position and text color
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Thousands)')
    plt.title('Waterfall Chart Example', loc='left')  # Moved title to the left
    
    # Adding legend
    plt.legend(loc='upper left', bbox_to_anchor=(0, 1))
    
    # Custom legends in upper left side below title in a horizontal way
    custom_legends = [
        plt.Line2D([0], [0], color='lightcoral', lw=10),
        plt.Line2D([0], [0], color='lightgreen', lw=10),
        plt.Line2D([0], [0], color='lightyellow', lw=10),
        plt.Line2D([0], [0], color='blue', lw=10),
    ]
    custom_legend_labels = ['Increase', 'Decrease', 'Other', 'Total']
    plt.legend(custom_legends, custom_legend_labels, loc='lower left', bbox_to_anchor=(0, 0.85), ncol=4)
    
    # Adjust y-axis limits to add space above the graph
    plt.ylim(top=cumsum + 5)  # You can adjust the value as needed
    
    # Remove the top and right spines
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    
    # Show the plot
    plt.tight_layout(rect=[0, 0.03, 1, 0.97])  # Adjusted layout with more space at the top
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart with updated colors, removed border, added legend, and custom legends
waterfall_chart(categories, values)

# %%
import matplotlib.pyplot as plt
import numpy as np

def format_number(value):
    return '{:.0f}k'.format(value)

def get_bar_color(category, value, next_value):
    if next_value is None:
        return 'green', 'Increase'  # Increasing bar
    if category == 'MTM':
        return 'mediumslateblue', 'Total'  # First bar is blue
    elif value < next_value and category != 'Other':
        return 'green', 'Increase'  # Increasing bar
    elif value > next_value and category != 'Other':
        return 'indianred', 'Decrease'  # Decreasing bar
    elif category == 'Other':
        return 'gold', 'Other'  # 'Other' bar is light yellow
    else:
        return 'gray', 'Unchanged'  # Unchanged bar

def waterfall_chart(categories, values):
    plt.figure(figsize=(14, 5))  # Adjusted the size of the graph
    
    # Convert values to thousands
    values_in_thousands = np.array(values) / 1000
    
    # Initialize the cumulative sum to 0
    cumsum = 0
    
    # Plotting the waterfall bars with formatted value labels
    for i, (category, value) in enumerate(zip(categories, values_in_thousands)):
        bar_color, legend_label = get_bar_color(category, value, values_in_thousands[i + 1] if i < len(categories) - 1 else None)
        plt.bar(category, value, bottom=cumsum, color=bar_color, edgecolor='none', label=legend_label)  # Added label for legend
        plt.text(category, cumsum + value + 0.3, format_number(value), ha='center', color='black')  # Adjusted the vertical position and text color
        cumsum += value
        
        # Draw lines between bars (except for the last bar)
        if i < len(categories) - 1:
            plt.plot([category, categories[i + 1]], [cumsum, cumsum], color='gray', linestyle='dotted', linewidth=0.8)
    
    # Adding the last cumulative bar
    plt.bar('udd', cumsum, color='mediumslateblue', edgecolor='none', label='Total')  # Added label for legend
    plt.text('udd', cumsum + 0.3, format_number(cumsum), ha='center', color='black')  # Adjusted the vertical position and text color
    
    # Setting x-axis ticks and labels
    plt.xticks(categories + ['udd'])
    
    # Adding labels and title
    plt.xlabel('Categories')
    plt.ylabel('Values (in Thousands)')
    plt.title('Waterfall Chart Example', loc='left')  # Moved title to the left
    
    # Adding legend
    plt.legend(loc='upper left', bbox_to_anchor=(0, 1))
    
    # Custom legends in upper left side below title in a horizontal way with small circles
    custom_legends = [
        plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='lightcoral', markersize=10),
        plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10),
        plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='gold', markersize=10),
        plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10),
    ]
    custom_legend_labels = ['Increase', 'Decrease', 'Other', 'Total']
    plt.legend(custom_legends, custom_legend_labels, loc='lower left', bbox_to_anchor=(0, 0.85), ncol=4)
    
    # Adjust y-axis limits to add space above the graph
    plt.ylim(top=cumsum + 300)  # You can adjust the value as needed
    
    # Remove the top and right spines
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    
    # Show the plot
    plt.tight_layout(rect=[0, 0.03, 1, 0.97])  # Adjusted layout with more space at the top
    plt.show()

# Example data
categories = ['MTM', 'New Build Rock', 'Prov Sums', 'New Build', 'Aerial', 'New Pits', 'Cable Installation (UG)', 'Other', 'Pit Rems']
values = [1401000, 584000, 215000, 195000, 104000, 50000, 35000, 5000, -24000]

# Create a waterfall chart with updated colors, removed border, added legend, and custom legends with circles
waterfall_chart(categories, values)
